# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
wind_ava = pd.read_csv('wind_ava.csv.gz', compression="gzip")

# %%
#Convertimos datetime en indice
wind_ava = wind_ava.set_index('datetime')

# %%
# Convertirmos el indice en objeto tiempo
wind_ava.index = pd.to_datetime(wind_ava.index)

# %%
for c in wind_ava.columns:
    if not c.endswith('.13') and c != 'energy':
        wind_ava.drop(c, axis = 1, inplace=True)

# %% [markdown]
# ## DATASET

# %%
wind_ava
# Out:
#                       energy    p54.162.13  p55.162.13    cape.13  \
# datetime
# 2005-01-02 18:00:00   402.71  2.510824e+06    9.186295  13.527577
# 2005-01-03 00:00:00   696.80  2.513173e+06    8.849569   6.896412
# 2005-01-03 06:00:00  1591.15  2.509627e+06    7.924080   4.774439
# 2005-01-03 12:00:00  1338.62  2.510571e+06    6.922709   0.000000
# 2005-01-03 18:00:00   562.50  2.505664e+06    6.646282   0.000000
# ...                      ...           ...         ...        ...
# 2009-12-30 06:00:00  1280.13  2.385772e+06   14.413342  24.971074
# 2009-12-30 12:00:00   855.00  2.385708e+06   12.802883  60.248874
# 2009-12-30 18:00:00   117.06  2.379049e+06   10.915997   3.145067
# 2009-12-31 12:00:00   516.96  2.371697e+06   13.048144  12.580268
# 2009-12-31 18:00:00   867.07  2.369547e+06    9.172745   8.487892
#
#                        p59.162.13  lai_lv.13  lai_hv.13   u10n.13   v10n.13  \
# datetime
# 2005-01-02 18:00:00  1.386937e+06   2.344111   2.432983 -0.757587 -1.922799
# 2005-01-03 00:00:00  1.153526e+06   2.343719   2.432838 -1.412620 -1.403011
# 2005-01-03 06:00:00  1.098754e+06   2.343300   2.432704 -2.290185 -0.754580
# 2005-01-03 12:00:00  1.076021e+06   2.342830   2.432514 -3.497855  1.271028
# 2005-01-03 18:00:00  1.070830e+06   2.342437   2.432369 -0.971249  0.553060
# ...                           ...        ...        ...       ...       ...
# 2009-12-30 06:00:00  3.905586e+06   2.349839   2.434994  4.595786  5.563189
# 2009-12-30 12:00:00  2.745694e+06   2.349446   2.434849  4.894838  5.577096
# 2009-12-30 18:00:00  2.254171e+06   2.349054   2.434715  0.958361  0.948029
# 2009-12-31 12:00:00  1.376913e+06   2.347799   2.434291  5.278912  0.771754
# 2009-12-31 18:00:00  1.356687e+06   2.347406   2.434145  4.578042  1.295018
#
#                             sp.13  ...      t2m.13     stl2.13     stl3.13  \
# datetime                           ...
# 2005-01-02 18:00:00  99846.319914  ...  280.473098  281.042026  281.462478
# 2005-01-03 00:00:00  99917.733093  ...  278.286616  280.747406  281.486541
# 2005-01-03 06:00:00  99764.378681  ...  277.206490  280.114863  281.487095
# 2005-01-03 12:00:00  99672.670459  ...  280.926600  279.991138  281.472435
# 2005-01-03 18:00:00  99372.811211  ...  277.363875  280.576898  281.473265
# ...                           ...  ...         ...         ...         ...
# 2009-12-30 06:00:00  95460.434452  ...  280.731326  282.643490  281.676560
# 2009-12-30 12:00:00  95663.765406  ...  283.310687  282.370909  281.761750
# 2009-12-30 18:00:00  95653.110509  ...  281.060085  282.425812  281.841961
# 2009-12-31 12:00:00  95534.765044  ...  279.662858  281.153379  281.976385
# 2009-12-31 18:00:00  95866.081608  ...  277.552154  281.046666  281.997129
#
#                       iews.13   inss.13     stl4.13    fsr.13   flsr.13  \
# datetime
# 2005-01-02 18:00:00 -0.057958 -0.138650  284.684755  0.404731 -5.927092
# 2005-01-03 00:00:00 -0.103576 -0.083050  284.667948  0.404920 -5.913881
# 2005-01-03 06:00:00 -0.165721 -0.036241  284.651914  0.405704 -5.908272
# 2005-01-03 12:00:00 -0.275550  0.098192  284.636266  0.403967 -5.961995
# 2005-01-03 18:00:00 -0.056553  0.041844  284.620232  0.403808 -5.987860
# ...                       ...       ...         ...       ...       ...
# 2009-12-30 06:00:00  0.628948  0.879581  286.013271  0.424510 -5.715421
# 2009-12-30 12:00:00  0.740926  0.699769  285.988737  0.424762 -5.732455
# 2009-12-30 18:00:00  0.109802  0.125174  285.968452  0.415132 -5.866856
# 2009-12-31 12:00:00  0.705886  0.192834  285.904895  0.426707 -5.693542
# 2009-12-31 18:00:00  0.460114  0.160810  285.884804  0.426651 -5.699429
#
#                       u100.13   v100.13
# datetime
# 2005-01-02 18:00:00 -1.780562 -4.443617
# 2005-01-03 00:00:00 -3.743344 -3.129469
# 2005-01-03 06:00:00 -5.097203 -1.157748
# 2005-01-03 12:00:00 -4.500835  1.502478
# 2005-01-03 18:00:00 -3.392324  2.131114
# ...                       ...       ...
# 2009-12-30 06:00:00  6.922743  9.179816
# 2009-12-30 12:00:00  7.434887  7.537381
# 2009-12-30 18:00:00  3.033799  3.568993
# 2009-12-31 12:00:00  8.374951  2.219422
# 2009-12-31 18:00:00  7.103223  1.883651
#
# [4748 rows x 23 columns]

# %%
X = wind_ava.drop(columns=['energy'])
y = wind_ava['energy']

# %% [markdown]
# # SPLIT

# %%
X_train = X.loc[:'2009-03-03']
y_train = y.loc[:'2009-03-03']

X_test = X.loc['2009-03-04':]
y_test = y.loc['2009-03-04':]

# %%
X_train
# Out:
#                        p54.162.13  p55.162.13    cape.13    p59.162.13  \
# datetime
# 2005-01-02 18:00:00  2.510824e+06    9.186295  13.527577  1.386937e+06
# 2005-01-03 00:00:00  2.513173e+06    8.849569   6.896412  1.153526e+06
# 2005-01-03 06:00:00  2.509627e+06    7.924080   4.774439  1.098754e+06
# 2005-01-03 12:00:00  2.510571e+06    6.922709   0.000000  1.076021e+06
# 2005-01-03 18:00:00  2.505664e+06    6.646282   0.000000  1.070830e+06
# ...                           ...         ...        ...           ...
# 2008-02-24 00:00:00  2.466893e+06   19.370060   0.000000  1.227631e+06
# 2008-02-24 06:00:00  2.458941e+06   20.859243  17.809416  1.104303e+06
# 2008-02-24 12:00:00  2.461805e+06   21.490690   9.852017  6.612880e+05
# 2009-03-06 06:00:00  280.021169  ...  280.604835  280.368499  280.944976
# 2009-03-06 12:00:00  281.388071  ...  283.342747  280.544034  280.934465
# ...                         ...  ...         ...         ...         ...
# 2009-12-30 06:00:00  281.680110  ...  280.731326  282.643490  281.676560
# 2009-12-30 12:00:00  282.842686  ...  283.310687  282.370909  281.761750
# 2009-12-30 18:00:00  282.027412  ...  281.060085  282.425812  281.841961
# 2009-12-31 12:00:00  280.814135  ...  279.662858  281.153379  281.976385
# 2009-12-31 18:00:00  279.805690  ...  277.552154  281.046666  281.997129
#
#                       iews.13   inss.13     stl4.13    fsr.13   flsr.13  \
# datetime
# 2009-03-05 12:00:00  0.912900 -1.280752  281.491062  0.416409 -5.881434
# 2009-03-05 18:00:00  0.611511 -0.674134  281.488937  0.416948 -5.864654
# 2009-03-06 00:00:00  0.199549 -0.167948  281.485846  0.425721 -5.725873
# 2009-03-06 06:00:00  0.203268 -0.128020  281.482948  0.428183 -5.689463
# 2009-03-06 12:00:00  0.549779 -0.523689  281.480437  0.428149 -5.704852
# ...                       ...       ...         ...       ...       ...
# 2009-12-30 06:00:00  0.628948  0.879581  286.013271  0.424510 -5.715421
# 2009-12-30 12:00:00  0.740926  0.699769  285.988737  0.424762 -5.732455
# 2009-12-30 18:00:00  0.109802  0.125174  285.968452  0.415132 -5.866856
# 2009-12-31 12:00:00  0.705886  0.192834  285.904895  0.426707 -5.693542
# 2009-12-31 18:00:00  0.460114  0.160810  285.884804  0.426651 -5.699429
#
#                       u100.13    v100.13
# datetime
# 2009-03-05 12:00:00  7.184308 -10.838239
# 2009-03-05 18:00:00  6.562830  -7.670114
# 2009-03-06 00:00:00  4.395505  -3.332029
# 2009-03-06 06:00:00  4.967808  -2.258858
# 2009-03-06 12:00:00  6.703552  -5.073250
# ...                       ...        ...
# 2009-12-30 06:00:00  6.922743   9.179816
# 2009-12-30 12:00:00  7.434887   7.537381
# 2009-12-30 18:00:00  3.033799   3.568993
# 2009-12-31 12:00:00  8.374951   2.219422
# 2009-12-31 18:00:00  7.103223   1.883651
#
# [921 rows x 22 columns]

# %%
y_train
# Out:
# datetime
# 2005-01-02 18:00:00     402.71
# 2005-01-03 00:00:00     696.80
# 2005-01-03 06:00:00    1591.15
# 2005-01-03 12:00:00    1338.62
# 2005-01-03 18:00:00     562.50
#                         ...
# 2008-02-24 00:00:00      64.34
# 2008-02-24 06:00:00      14.95
# 2008-02-24 12:00:00     171.21
# 2008-02-25 06:00:00       2.35
# 2008-02-25 18:00:00      46.62
# Name: energy, Length: 3827, dtype: float64

# %%
y_test
# Out:
# datetime
# 2009-03-05 12:00:00     977.91
# 2009-03-05 18:00:00    1191.99
# 2009-03-06 00:00:00     795.88
# 2009-03-06 06:00:00     141.05
# 2009-03-06 12:00:00    1124.20
#                         ...
# 2009-12-30 06:00:00    1280.13
# 2009-12-30 12:00:00     855.00
# 2009-12-30 18:00:00     117.06
# 2009-12-31 12:00:00     516.96
# 2009-12-31 18:00:00     867.07
# Name: energy, Length: 921, dtype: float64

# %% [markdown]
# # Método de escalado

# %% [markdown]
# ## Con HPO

# %%
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.metrics import r2_score


inner_tss = TimeSeriesSplit(n_splits=4)

inner_scores = {}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, f_regression

best_scores = {}

param_grid = {'knn__n_neighbors': [3, 5, 7, 9, 11, 13, 15]}

pipeline_std = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsRegressor())
])

# Definir GridSearchCV para StandardScaler
grid_std = GridSearchCV(pipeline_std, 
                        param_grid, 
                        scoring='r2',
                        cv=inner_tss)

grid_std.fit(X_train, y_train)
best_scores['StandardScaler'] = grid_std.best_score_

pipeline_min_max = Pipeline([
    ('scaler', MinMaxScaler()),
    ('knn', KNeighborsRegressor())
])

# Definir GridSearchCV para MinMaxScaler
grid_min_max = GridSearchCV(pipeline_min_max, 
                           param_grid, 
                           scoring='r2',
                           cv=inner_tss)

grid_min_max.fit(X_train, y_train)
best_scores['MinMaxScaler'] = grid_min_max.best_score_

pipeline_robust = Pipeline([
    ('scaler', RobustScaler()),
    ('knn', KNeighborsRegressor())
])

# Definir GridSearchCV para RobustScaler
grid_robust = GridSearchCV(pipeline_robust, 
                           param_grid, 
                           scoring='r2', 
                           cv=inner_tss)
                           
grid_robust.fit(X_train, y_train)
best_scores['RobustScaler'] = grid_robust.best_score_

# Definir GridSearchCV para KNN sin scaler
param_grid_b = {'n_neighbors': [3, 5, 7, 9, 11, 13, 15]}
                           
grid_knn = GridSearchCV(KNeighborsRegressor(), 
                        param_grid_b, 
                        scoring='r2', 
                        cv=inner_tss)
                           
grid_knn.fit(X_train, y_train)
best_scores['KNN'] = grid_knn.best_score_

# Mostrar los resultados
for name, score in best_scores.items():
    print(f"{name}: {score}")
# Out:
# StandardScaler: 0.588268910791875
# MinMaxScaler: 0.5261399320713689
# RobustScaler: 0.5740368124442256
# KNN: 0.18860883013688512

# %% [markdown]
# # EVALUACIÓN DE MODELOS

# %% [markdown]
# ## CON HPO

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
import time

scores_with_hpo = {}

"""MODELO 1: KNN"""

# Hiper-parámetros
param_grid_knn = {
    'knn__n_neighbors': [3, 5, 7, 9, 11],
    'knn__weights': ['uniform', 'distance'],
    'knn__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
}

pipeline_knn_std = Pipeline([
    ('feature_selection', SelectKBest(score_func=f_regression)),
    ('scaler', StandardScaler()),
    ('knn', KNeighborsRegressor())
])

# GridSearch
grid_search_knn = GridSearchCV(
    estimator=pipeline_knn_std,
    param_grid=param_grid_knn,
    scoring='r2',  # Using negative MSE as a score
    cv=inner_tss
)

# Entrenamiento
time_start = time.time()
grid_search_knn.fit(X_train, y_train)
time_end = time.time()
total_time_training_hpo = time_end - time_start



# MODELO 1: Linear Regression
param_grid_lr = {}

pipeline_lr_std = Pipeline([
    ('feature_selection', SelectKBest(score_func=f_regression)),
    ('scaler', StandardScaler()),
    ('lr', LinearRegression())
])

grid_search_lr = GridSearchCV(
    estimator=pipeline_lr_std,
    param_grid=param_grid_lr,
    scoring='r2',
    cv=inner_tss
)

time_start = time.time()
grid_search_lr.fit(X_train, y_train)
time_end = time.time()
total_time_training_lr = time_end - time_start

# MODELO 2: Lasso
param_grid_lasso = {
    'lasso__alpha': [0.001, 0.01, 0.1, 1, 10]
}

pipeline_lasso_std = Pipeline([
    ('feature_selection', SelectKBest(score_func=f_regression)),
    ('scaler', StandardScaler()),
    ('lasso', Lasso())
])

grid_search_lasso = GridSearchCV(
    estimator=pipeline_lasso_std,
    param_grid=param_grid_lasso,
    scoring='r2',
    cv=inner_tss
)

time_start = time.time()
grid_search_lasso.fit(X_train, y_train)
time_end = time.time()
total_time_training_lasso = time_end - time_start

# MODELO 3: Ridge
param_grid_ridge = {
    'ridge__alpha': [0.001, 0.01, 0.1, 1, 10]
}

pipeline_ridge_std = Pipeline([
    ('feature_selection', SelectKBest(score_func=f_regression)),
    ('scaler', StandardScaler()),
    ('ridge', Ridge())
])

grid_search_ridge = GridSearchCV(
    estimator=pipeline_ridge_std,
    param_grid=param_grid_ridge,
    scoring='r2',
    cv=inner_tss
)

time_start = time.time()
grid_search_ridge.fit(X_train, y_train)
time_end = time.time()
total_time_training_ridge = time_end - time_start

# MODELO 4: ElasticNet
param_grid_elasticnet = {
    'elasticnet__alpha': [0.001, 0.01, 0.1, 1, 10],
    'elasticnet__l1_ratio': [0.1, 0.3, 0.5, 0.7, 0.9]
}

pipeline_elasticnet_std = Pipeline([
    ('feature_selection', SelectKBest(score_func=f_regression)),
    ('scaler', StandardScaler()),
    ('elasticnet', ElasticNet())
])

grid_search_elasticnet = GridSearchCV(
    estimator=pipeline_elasticnet_std,
    param_grid=param_grid_elasticnet,
    scoring='r2',
    cv=inner_tss
)

time_start = time.time()
grid_search_elasticnet.fit(X_train, y_train)
time_end = time.time()
total_time_training_elasticnet = time_end - time_start

# MODELO 5: SVR
param_grid_svr = {
    'svr__C': [0.1, 1, 10, 100],
    'svr__gamma': ['scale', 'auto'],
    'svr__kernel': ['linear', 'poly', 'rbf', 'sigmoid']
}

pipeline_svr_std = Pipeline([
    ('feature_selection', SelectKBest(score_func=f_regression)),
    ('scaler', StandardScaler()),
    ('svr', SVR())
])

grid_search_svr = GridSearchCV(
    estimator=pipeline_svr_std,
    param_grid=param_grid_svr,
    scoring='r2',
    cv=inner_tss
)

time_start = time.time()
grid_search_svr.fit(X_train, y_train)
time_end = time.time()
total_time_training_svr = time_end - time_start

# MODELO 6: Árboles de Decisión
param_grid_dt = {
    'dt__max_depth': [None, 10, 20, 30, 50],
    'dt__min_samples_split': [2, 5, 10],
    'dt__min_samples_leaf': [1, 2, 4]
}

pipeline_dt = Pipeline([
    ('feature_selection', SelectKBest(score_func=f_regression)),
    ('scaler', StandardScaler()),
    ('dt', DecisionTreeRegressor())
])

grid_search_dt = GridSearchCV(
    estimator=pipeline_dt,
    param_grid=param_grid_dt,
    scoring='r2',
    cv=inner_tss
)

time_start = time.time()
grid_search_dt.fit(X_train, y_train)
time_end = time.time()
total_time_training_dt = time_end - time_start

# Recopilación de resultados
scores_with_hpo = {}

scores_with_hpo['KNN'] = {'R^2': r2_score(y_test, grid_search_knn.predict(X_test)), 'Training Time': total_time_training_hpo}
scores_with_hpo['Linear'] = {'R^2': r2_score(y_test, grid_search_lr.predict(X_test)), 'Training Time': total_time_training_lr}
scores_with_hpo['Lasso'] = {'R^2': r2_score(y_test, grid_search_lasso.predict(X_test)), 'Training Time': total_time_training_lasso}
scores_with_hpo['Ridge'] = {'R^2': r2_score(y_test, grid_search_ridge.predict(X_test)), 'Training Time': total_time_training_ridge}
scores_with_hpo['ElasticNet'] = {'R^2': r2_score(y_test, grid_search_elasticnet.predict(X_test)), 'Training Time': total_time_training_elasticnet}
scores_with_hpo['SVR'] = {'R^2': r2_score(y_test, grid_search_svr.predict(X_test)), 'Training Time': total_time_training_svr}
scores_with_hpo['Decision Tree'] = {'R^2': r2_score(y_test, grid_search_dt.predict(X_test)), 'Training Time': total_time_training_dt}
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.201e+08, tolerance: 2.966e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.305e+08, tolerance: 6.968e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.550e+08, tolerance: 1.001e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.704e+08, tolerance: 1.359e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.898e+07, tolerance: 2.966e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.080e+08, tolerance: 6.968e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.819e+08, tolerance: 1.001e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.323e+08, tolerance: 1.359e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.371e+07, tolerance: 2.966e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.563e+06, tolerance: 6.968e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.731e+07, tolerance: 1.001e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.238e+08, tolerance: 1.359e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.653e+05, tolerance: 1.359e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.896e+08, tolerance: 1.693e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.208e+08, tolerance: 2.966e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.452e+08, tolerance: 6.968e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.590e+08, tolerance: 1.001e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.759e+08, tolerance: 1.359e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.178e+08, tolerance: 2.966e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.263e+08, tolerance: 6.968e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.529e+08, tolerance: 1.001e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.736e+08, tolerance: 1.359e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.176e+08, tolerance: 2.966e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.212e+08, tolerance: 6.968e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.517e+08, tolerance: 1.001e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.724e+08, tolerance: 1.359e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.185e+08, tolerance: 2.966e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.247e+08, tolerance: 6.968e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.526e+08, tolerance: 1.001e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.715e+08, tolerance: 1.359e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.196e+08, tolerance: 2.966e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.286e+08, tolerance: 6.968e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.542e+08, tolerance: 1.001e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.708e+08, tolerance: 1.359e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.999e+05, tolerance: 1.359e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.781e+05, tolerance: 6.968e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.259e+07, tolerance: 1.359e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.436e+07, tolerance: 2.966e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.599e+06, tolerance: 6.968e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.576e+07, tolerance: 1.001e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.909e+08, tolerance: 1.359e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.899e+08, tolerance: 1.693e+05
#   model = cd_fast.enet_coordinate_descent(

# %%
# Crea un DataFrame a partir de los diccionarios
df = pd.DataFrame.from_dict(scores_with_hpo, orient='index')

# Imprime el DataFrame
df
# Out:
#                     R^2  Training Time
# KNN            0.604310       5.119829
# Linear         0.285407       0.041516
# Lasso          0.285342       0.477635
# Ridge          0.285406       0.181173
# ElasticNet     0.285212       1.697142
# SVR            0.602583      53.545749
# Decision Tree  0.547741       5.533872
